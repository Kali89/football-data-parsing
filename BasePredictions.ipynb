# %%
## Importing required libraries
import sqlite3
import pandas as pd
import numpy as np
import seaborn as sns
import itertools
import matplotlib.pyplot as plt
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn import linear_model
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, accuracy_score
from sklearn.calibration import CalibratedClassifierCV
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer
from time import time
from sklearn.decomposition import PCA, FastICA
from sklearn.pipeline import Pipeline
import matplotlib
matplotlib.rcParams['figure.figsize'] = [20, 12]

# %%
def get_match_label(match):
    ''' Derives a label for a given match. '''
    
    #Define variables
    home_goals = match['home_team_goal']
    away_goals = match['away_team_goal']

    #Identify match label  
    if home_goals > away_goals:
        return 'Win'
    if home_goals == away_goals:
        return 'Draw'
    if home_goals < away_goals:
        return 'Defeat'

# %%
def get_last_matches(matches, date, team, x = 10):
    ''' Get the last x matches of a given team. '''
    
    #Filter team matches from matches
    team_matches = matches[(matches['home_team_api_id'] == team) | (matches['away_team_api_id'] == team)]
                           
    #Filter x last matches from team matches
    last_matches = team_matches[team_matches.date < date].sort_values(by = 'date', ascending = False).iloc[0:x,:]
    
    #Return last matches
    return last_matches

# %%
def get_last_matches_against_eachother(matches, date, home_team, away_team, x = 10):
    ''' Get the last x matches of two given teams. '''
    
    #Find matches of both teams
    home_matches = matches[(matches['home_team_api_id'] == home_team) & (matches['away_team_api_id'] == away_team)]    
    away_matches = matches[(matches['home_team_api_id'] == away_team) & (matches['away_team_api_id'] == home_team)]  
    total_matches = pd.concat([home_matches, away_matches])
    
    #Get last x matches
    try:    
        last_matches = total_matches[total_matches.date < date].sort_values(by = 'date', ascending = False).iloc[0:x,:]
    except:
        last_matches = total_matches[total_matches.date < date].sort_values(by = 'date', ascending = False).iloc[0:total_matches.shape[0],:]
        
        #Check for error in data
        if(last_matches.shape[0] > x):
            print("Error in obtaining matches")
            
    #Return data
    return last_matches

# %%
def convert_odds_to_prob(match_odds):
    ''' Converts bookkeeper odds to probabilities. '''
    
    #Define variables
    match_id = match_odds.loc[:,'match_api_id']
    bookkeeper = match_odds.loc[:,'bookkeeper']    
    win_odd = match_odds.loc[:,'Win']
    draw_odd = match_odds.loc[:,'Draw']
    loss_odd = match_odds.loc[:,'Defeat']
    
    #Converts odds to prob
    win_prob = 1 / win_odd
    draw_prob = 1 / draw_odd
    loss_prob = 1 / loss_odd
    
    total_prob = win_prob + draw_prob + loss_prob
    
    probs = pd.DataFrame()
    
    #Define output format and scale probs by sum over all probs
    probs.loc[:,'match_api_id'] = match_id
    probs.loc[:,'bookkeeper'] = bookkeeper
    probs.loc[:,'Win'] = win_prob / total_prob
    probs.loc[:,'Draw'] = draw_prob / total_prob
    probs.loc[:,'Defeat'] = loss_prob / total_prob
    
    #Return probs and meta data
    return probs

# %% [markdown]
# ### Doing things now...

# %%
## Fetching data
#Connecting to database
path = "soccer_database.sqlite"  #Insert path here
conn = sqlite3.connect(path)

#Defining the number of jobs to be run in parallel during grid search
n_jobs = 2 #Insert number of parallel jobs here

#Fetching required data tables
player_data = pd.read_sql("SELECT * FROM Player;", conn)
player_stats_data = pd.read_sql("SELECT * FROM Player_Attributes;", conn)
team_data = pd.read_sql("SELECT * FROM Team;", conn)
match_data = pd.read_sql("SELECT * FROM Match where country_id = 1729;", conn)

match_data.head(5)
# Out:
#      id  country_id  league_id     season  stage                 date  \
# 0  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1  1730        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 2  1731        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 3  1732        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 4  1733        1729       1729  2008/2009      1  2008-08-17 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  ...    \
# 0        489042             10260             10261               1  ...
# 1        489043              9825              8659               1  ...
# 2        489044              8472              8650               0  ...
# 3        489045              8654              8528               2  ...
# 4        489046             10252              8456               4  ...
#
#      SJA   VCH  VCD    VCA   GBH   GBD   GBA   BSH   BSD    BSA
# 0  10.00  1.28  5.5  12.00  1.30  4.75  10.0  1.29  4.50  11.00
# 1  12.00  1.25  6.0  13.00  1.22  5.50  13.0  1.22  5.00  13.00
# 2   1.73  5.50  3.8   1.65  5.00  3.40   1.7  4.50  3.40   1.73
# 3   3.75  1.90  3.5   4.35  1.91  3.25   4.0  1.91  3.25   3.80
# 4   3.75  1.90  3.5   4.35  1.91  3.25   4.0  1.91  3.30   3.75
#
# [5 rows x 115 columns]

# %%
team_data.head(5)
# Out:
#    id  team_api_id  team_fifa_api_id     team_long_name team_short_name
# 0   1         9987             673.0           KRC Genk             GEN
# 1   2         9993             675.0       Beerschot AC             BAC
# 2   3        10000           15005.0   SV Zulte-Waregem             ZUL
# 3   4         9994            2007.0   Sporting Lokeren             LOK
# 4   5         9984            1750.0  KSV Cercle Brugge             CEB

# %%
player_data.head(5)
# Out:
#    id  player_api_id         player_name  player_fifa_api_id  \
# 0   1         505942  Aaron Appindangoye              218353
# 1   2         155782     Aaron Cresswell              189615
# 2   3         162549         Aaron Doran              186170
# 3   4          30572       Aaron Galindo              140161
# 4   5          23780        Aaron Hughes               17725
#
#               birthday  height  weight
# 0  1992-02-29 00:00:00  182.88     187
# 1  1989-12-15 00:00:00  170.18     146
# 2  1991-05-13 00:00:00  170.18     163
# 3  1982-05-08 00:00:00  182.88     198
# 4  1979-11-08 00:00:00  182.88     154

# %%
with_team_names = match_data.merge(
    team_data, 
    how='inner', 
    left_on=['home_team_api_id'], 
    right_on=['team_api_id'], 
    suffixes=('', '_home')
).merge(
    team_data, 
    how='inner', 
    left_on=['away_team_api_id'], 
    right_on=['team_api_id'], 
    suffixes=('', '_away')
)
with_team_names.head(5)
# Out:
#      id  country_id  league_id     season  stage                 date  \
# 0  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1  2494        1729       1729  2010/2011      1  2010-08-16 00:00:00
# 2  2913        1729       1729  2011/2012     13  2011-11-26 00:00:00
# 3  3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 4  3693        1729       1729  2013/2014     15  2013-12-07 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0        489042             10260             10261               1
# 1        839802             10260             10261               3
# 2       1024845             10260             10261               1
# 3       1229300             10260             10261               4
# 4       1474518             10260             10261               0
#
#            ...           id_home  team_api_id  team_fifa_api_id  \
# 0          ...              3457        10260              11.0
# 1          ...              3457        10260              11.0
# 2          ...              3457        10260              11.0
# 3          ...              3457        10260              11.0
# 4          ...              3457        10260              11.0
#
#       team_long_name  team_short_name  id_away  team_api_id_away  \
# 0  Manchester United              MUN     3458             10261
# 1  Manchester United              MUN     3458             10261
# 2  Manchester United              MUN     3458             10261
# 3  Manchester United              MUN     3458             10261
# 4  Manchester United              MUN     3458             10261
#
#    team_fifa_api_id_away  team_long_name_away  team_short_name_away
# 0                   13.0     Newcastle United                   NEW
# 1                   13.0     Newcastle United                   NEW
# 2                   13.0     Newcastle United                   NEW
# 3                   13.0     Newcastle United                   NEW
# 4                   13.0     Newcastle United                   NEW
#
# [5 rows x 125 columns]

# %%
import operator
import xml.etree as ET

def get_posession_things(data):
    last_value = 50
    try:
        tree = ET.fromstring(data)
        results = tree.findall('value')
        results_dict = dict((result.find('elapsed').text, result.find('homepos').text) for result in results)
        last_value = [value for key, value in sorted(results_dict.items(), key=operator.itemgetter(1), reverse=True)][0]
    except:
        pass
    
    return last_value

# %%
with_team_names.loc[:, 'home_possession'] = with_team_names.possession.apply(lambda x: get_posession_things(x))

# %%
with_team_names.loc[:, 'total_prob'] = 1./with_team_names.B365H + 1./with_team_names.B365D + 1./with_team_names.B365A
with_team_names.loc[:, 'pct_win_prob'] = (1./ with_team_names.B365H) / with_team_names.total_prob
with_team_names.head(5)
# Out:
#      id  country_id  league_id     season  stage                 date  \
# 0  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1  2494        1729       1729  2010/2011      1  2010-08-16 00:00:00
# 2  2913        1729       1729  2011/2012     13  2011-11-26 00:00:00
# 3  3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 4  3693        1729       1729  2013/2014     15  2013-12-07 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0        489042             10260             10261               1
# 1        839802             10260             10261               3
# 2       1024845             10260             10261               1
# 3       1229300             10260             10261               4
# 4       1474518             10260             10261               0
#
#        ...          team_long_name  team_short_name  id_away  \
# 0      ...       Manchester United              MUN     3458
# 1      ...       Manchester United              MUN     3458
# 2      ...       Manchester United              MUN     3458
# 3      ...       Manchester United              MUN     3458
# 4      ...       Manchester United              MUN     3458
#
#    team_api_id_away  team_fifa_api_id_away  team_long_name_away  \
# 0             10261                   13.0     Newcastle United
# 1             10261                   13.0     Newcastle United
# 2             10261                   13.0     Newcastle United
# 3             10261                   13.0     Newcastle United
# 4             10261                   13.0     Newcastle United
#
#    team_short_name_away  home_possession  total_prob  pct_win_prob
# 0                   NEW               50    1.047921      0.739744
# 1                   NEW               50    1.048485      0.763006
# 2                   NEW               50    1.054155      0.677591
# 3                   NEW               50    1.050441      0.780312
# 4                   NEW               50    1.027399      0.636165
#
# [5 rows x 128 columns]

# %% [markdown]
# ## Work out how good each team is

# %%
HISTORY = 10
k_factor = 32
elo_width = 400.

def calculate_new_elos(rating_a, rating_b, score_a, k_factor, elo_width):
    """Calculates and returns the new Elo ratings for two players.
    score_a is 1 for a win by player A, 0 for a loss by player A, or 0.5 for a draw.
    """

    e_a = expected_result(rating_a, rating_b, elo_width)
    e_b = 1. - e_a
    new_rating_a = rating_a + k_factor * (score_a - e_a)
    score_b = 1. - score_a
    new_rating_b = rating_b + k_factor * (score_b - e_b)
    return new_rating_a, new_rating_b

def expected_result(elo_a, elo_b, elo_width):
    """
    https://en.wikipedia.org/wiki/Elo_rating_system#Mathematical_details
    """
    expect_a = 1.0/(1+10**((elo_b - elo_a)/elo_width))
    return expect_a

def update_end_of_season(elos):
    """Regression towards the mean
    
    Following 538 nfl methods
    https://fivethirtyeight.com/datalab/nfl-elo-ratings-are-back/
    """
    diff_from_mean = elos - np.mean(elos)
    elos -= diff_from_mean/3
    return elos

# %%
team_elo = with_team_names.team_long_name.drop_duplicates().reset_index()
team_elo.loc[:, 'elo'] = 1000
team_elo = team_elo[['team_long_name', 'elo']]
with_team_names.loc[:, 'other_expected'] = 0.5
team_elo.head()
# Out:
#       team_long_name   elo
# 0  Manchester United  1000
# 1            Arsenal  1000
# 2         Sunderland  1000
# 3    West Ham United  1000
# 4        Aston Villa  1000

# %%
with_team_names.sort_values(by='date').head()
# Out:
#         id  country_id  league_id     season  stage                 date  \
# 1370  1737        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 661   1732        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 1194  1731        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 1643  1735        1729       1729  2008/2009      1  2008-08-16 00:00:00
# 1083  1734        1729       1729  2008/2009      1  2008-08-16 00:00:00
#
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 1370        489050              8667              9879               2
# 661         489045              8654              8528               2
# 1194        489044              8472              8650               0
# 1643        489048              8549              8586               2
# 1083        489047              8668              8655               2
#
#           ...        team_long_name  team_short_name  id_away  \
# 1370      ...             Hull City              HUL     3474
# 661       ...       West Ham United              WHU     3464
# 1194      ...            Sunderland              SUN     3462
# 1643      ...         Middlesbrough              MID     3470
# 1083      ...               Everton              EVE     3468
#
#       team_api_id_away  team_fifa_api_id_away  team_long_name_away  \
# 1370              9879                  144.0               Fulham
# 661               8528                 1917.0       Wigan Athletic
# 1194              8650                    9.0            Liverpool
# 1643              8586                   18.0    Tottenham Hotspur
# 1083              8655                    3.0     Blackburn Rovers
#
#       team_short_name_away  home_possession  total_prob  pct_win_prob
# 1370                   FUL               50    1.054258      0.364821
# 661                    WIG               50    1.055773      0.495902
# 1194                   LIV               50    1.058398      0.171786
# 1643                   TOT               50    1.051062      0.297318
# 1083                   BLB               50    1.053030      0.474820
#
# [5 rows x 128 columns]

# %%
def calculate_result(row):
    if row.home_team_goal > row.away_team_goal:
        return 1
    elif row.home_team_goal == row.away_team_goal:
        return 0.5
    else:
        return 0

# %%
def create_predictions(team_elo, col_name, k_factor, elo_width):
    current_season = '2008/2009'
    for index, row in with_team_names.sort_values(by='date').iterrows():
        new_season = row.season
        if new_season != current_season:
            new_elos = update_end_of_season(team_elo.elo.values)
            team_elo.loc[:, 'elo'] = new_elos
            current_season = new_season

        home = row.team_long_name
        away = row.team_long_name_away
        home_elo = team_elo[team_elo.team_long_name == home].elo.values[0]
        away_elo = team_elo[team_elo.team_long_name == away].elo.values[0]
        expected_results = expected_result(home_elo, away_elo, elo_width)
        result = calculate_result(row)
        with_team_names.loc[index, col_name] = expected_results
        new_home_elo, new_away_elo = calculate_new_elos(home_elo, away_elo, result, k_factor, elo_width)
        team_elo.loc[team_elo.team_long_name == home, 'elo'] = new_home_elo
        team_elo.loc[team_elo.team_long_name == away, 'elo'] = new_away_elo

# %%
create_predictions(team_elo, 'other_expected', 64, 200)

# %%
team_elo.sort_values(by='elo', ascending=False).head()
# Out:
#        team_long_name          elo
# 27        Southampton  1134.317762
# 30     Leicester City  1128.367028
# 25       Swansea City  1079.377265
# 0   Manchester United  1068.527899
# 1             Arsenal  1065.703243

# %%
with_team_names.head()
# Out:
#      id  country_id  league_id     season  stage                 date  \
# 0  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1  2494        1729       1729  2010/2011      1  2010-08-16 00:00:00
# 2  2913        1729       1729  2011/2012     13  2011-11-26 00:00:00
# 3  3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 4  3693        1729       1729  2013/2014     15  2013-12-07 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0        489042             10260             10261               1
# 1        839802             10260             10261               3
# 2       1024845             10260             10261               1
# 3       1229300             10260             10261               4
# 4       1474518             10260             10261               0
#
#         ...        team_api_id_away  team_fifa_api_id_away  \
# 0       ...                   10261                   13.0
# 1       ...                   10261                   13.0
# 2       ...                   10261                   13.0
# 3       ...                   10261                   13.0
# 4       ...                   10261                   13.0
#
#    team_long_name_away  team_short_name_away  home_possession  total_prob  \
# 0     Newcastle United                   NEW               50    1.047921
# 1     Newcastle United                   NEW               50    1.048485
# 2     Newcastle United                   NEW               50    1.054155
# 3     Newcastle United                   NEW               50    1.050441
# 4     Newcastle United                   NEW               50    1.027399
#
#    pct_win_prob  expected  resulty  other_expected
# 0      0.739744  0.500000      0.5        0.500000
# 1      0.763006  0.744386      1.0        0.744386
# 2      0.677591  0.648628      0.5        0.648628
# 3      0.780312  0.779633      1.0        0.779633
# 4      0.636165  0.629053      0.0        0.629053
#
# [5 rows x 131 columns]

# %%
with_team_names[with_team_names.season == '2012/2013']
# Out:
#         id  country_id  league_id     season  stage                 date  \
# 3     3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 10    3369        1729       1729  2012/2013     20  2012-12-29 00:00:00
# 17    3614        1729       1729  2012/2013      8  2012-10-21 00:00:00
# 23    3548        1729       1729  2012/2013     36  2013-05-04 00:00:00
# 30    3410        1729       1729  2012/2013     24  2013-01-29 00:00:00
# 37    3571        1729       1729  2012/2013      4  2012-09-17 00:00:00
# 51    3360        1729       1729  2012/2013      2  2012-08-25 00:00:00
# 58    3302        1729       1729  2012/2013     14  2012-11-28 00:00:00
# 65    3260        1729       1729  2012/2013     10  2012-11-04 00:00:00
# 72    3322        1729       1729  2012/2013     16  2012-12-10 00:00:00
# 77    3438        1729       1729  2012/2013     26  2013-02-09 00:00:00
# 84    3527        1729       1729  2012/2013     34  2013-04-20 00:00:00
# 92    3493        1729       1729  2012/2013     31  2013-03-30 00:00:00
# 102   3488        1729       1729  2012/2013     30  2013-03-17 00:00:00
# 109   3555        1729       1729  2012/2013     37  2013-05-12 00:00:00
# 112   3394        1729       1729  2012/2013     22  2013-01-12 00:00:00
# 116   3456        1729       1729  2012/2013     28  2013-03-02 00:00:00
# 120   3596        1729       1729  2012/2013      6  2012-09-29 00:00:00
# 121   3293        1729       1729  2012/2013     13  2012-11-25 00:00:00
# 136   3300        1729       1729  2012/2013     14  2012-11-28 00:00:00
# 143   3349        1729       1729  2012/2013     19  2013-01-23 00:00:00
# 150   3398        1729       1729  2012/2013     22  2013-01-12 00:00:00
# 157   3429        1729       1729  2012/2013     26  2013-02-10 00:00:00
# 164   3551        1729       1729  2012/2013     37  2013-05-12 00:00:00
# 179   3480        1729       1729  2012/2013     30  2013-03-17 00:00:00
# 186   3454        1729       1729  2012/2013     28  2013-03-02 00:00:00
# 193   3500        1729       1729  2012/2013     32  2013-04-07 00:00:00
# 199   3274        1729       1729  2012/2013     11  2012-11-11 00:00:00
# 206   3418        1729       1729  2012/2013     24  2013-01-30 00:00:00
# 211   3297        1729       1729  2012/2013     13  2012-11-25 00:00:00
# ...    ...         ...        ...        ...    ...                  ...
# 2725  3610        1729       1729  2012/2013      8  2012-10-20 00:00:00
# 2726  3402        1729       1729  2012/2013     23  2013-01-19 00:00:00
# 2727  3539        1729       1729  2012/2013     36  2013-05-04 00:00:00
# 2728  3385        1729       1729  2012/2013     21  2013-01-01 00:00:00
# 2729  3586        1729       1729  2012/2013      5  2012-09-22 00:00:00
# 2730  3341        1729       1729  2012/2013     18  2012-12-22 00:00:00
# 2731  3298        1729       1729  2012/2013     13  2012-11-24 00:00:00
# 2732  3263        1729       1729  2012/2013     10  2012-11-04 00:00:00
# 2733  3522        1729       1729  2012/2013     34  2013-04-20 00:00:00
# 2734  3604        1729       1729  2012/2013      7  2012-10-06 00:00:00
# 2735  3324        1729       1729  2012/2013     16  2012-12-08 00:00:00
# 2892  3529        1729       1729  2012/2013     35  2013-04-28 00:00:00
# 2900  3495        1729       1729  2012/2013     31  2013-03-30 00:00:00
# 2907  3468        1729       1729  2012/2013     29  2013-04-17 00:00:00
# 2915  3270        1729       1729  2012/2013     11  2012-11-10 00:00:00
# 2923  3250        1729       1729  2012/2013      1  2012-08-20 00:00:00
# 2940  3621        1729       1729  2012/2013      9  2012-10-28 00:00:00
# 2948  3517        1729       1729  2012/2013     33  2013-04-14 00:00:00
# 2956  3580        1729       1729  2012/2013      5  2012-09-23 00:00:00
# 2963  3602        1729       1729  2012/2013      7  2012-10-07 00:00:00
# 2971  3421        1729       1729  2012/2013     25  2013-02-02 00:00:00
# 2977  3405        1729       1729  2012/2013     23  2013-01-20 00:00:00
# 2984  3566        1729       1729  2012/2013     38  2013-05-19 00:00:00
# 2994  3323        1729       1729  2012/2013     16  2012-12-09 00:00:00
# 3006  3388        1729       1729  2012/2013     21  2013-01-01 00:00:00
# 3016  3445        1729       1729  2012/2013     27  2013-02-23 00:00:00
# 3019  3284        1729       1729  2012/2013     12  2012-11-17 00:00:00
# 3023  3344        1729       1729  2012/2013     18  2012-12-23 00:00:00
# 3027  3316        1729       1729  2012/2013     15  2012-12-01 00:00:00
# 3028  3473        1729       1729  2012/2013      3  2012-09-02 00:00:00
#
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 3          1229300             10260             10261               4
# 10         1229306              9825             10261               7
# 17         1229179              8472             10261               1
# 23         1229492              8654             10261               0
# 30         1229351             10252             10261               1
# 37         1228331              8668             10261               2
# 51         1228291              8455             10261               2
# 58         1229242             10194             10261               2
# 65         1229197              8650             10261               1
# 72         1229265              9879             10261               2
# 77         1229383              8586             10261               2
# 84         1229469              8659             10261               1
# 92         1229434              8456             10261               4
# 102        1229428              8528             10261               2
# 109        1229499             10172             10261               1
# 112        1229334              9850             10261               0
# 116        1229404             10003             10261               1
# 120        1228519              9798             10261               2
# 121        1229233              8466             10261               2
# 136        1229240             10260              8654               1
# 143        1229295              9825              8654               5
# 150        1229338              8472              8654               3
# 157        1229373             10252              8654               2
# 164        1229495              8668              8654               2
# 179        1229419              8455              8654               2
# 186        1229402             10194              8654               0
# 193        1229441              8650              8654               0
# 199        1229213             10261              8654               0
# 206        1229360              9879              8654               3
# 211        1229237              8586              8654               3
# ...            ...               ...               ...             ...
# 2725       1229175              8650              9798               1
# 2726       1229343             10261              9798               1
# 2727       1229482              9879              9798               2
# 2728       1229325              8586              9798               3
# 2729       1228388              8659              9798               1
# 2730       1229286              8456              9798               1
# 2731       1229238              8528              9798               3
# 2732       1229200             10172              9798               1
# 2733       1229464              9850              9798               2
# 2734       1229168             10003              9798               2
# 2735       1229268              8466              9798               1
# 2892       1229471              9825             10260               1
# 2900       1229436              8472             10260               0
# 2907       1229417              8654             10260               2
# 2915       1229209             10252             10260               2
# 2923       1228230              8668             10260               1
# 2940       1229187              8455             10260               2
# 2948       1229459             10194             10260               0
# 2956       1228368              8650             10260               1
# 2963       1229165             10261             10260               0
# 2971       1229363              9879             10260               0
# 2977       1229346              8586             10260               1
# 2984       1228315              8659             10260               5
# 2994       1229267              8456             10260               2
# 3006       1229328              8528             10260               0
# 3016       1229391             10172             10260               0
# 3019       1229223              9850             10260               1
# 3023       1229289             10003             10260               1
# 3027       1229258              9798             10260               3
# 3028       1228305              8466             10260               2
#
#            ...        team_fifa_api_id_away  team_long_name_away  \
# 3          ...                         13.0     Newcastle United
# 10         ...                         13.0     Newcastle United
# 17         ...                         13.0     Newcastle United
# 23         ...                         13.0     Newcastle United
# 30         ...                         13.0     Newcastle United
# 37         ...                         13.0     Newcastle United
# 51         ...                         13.0     Newcastle United
# 58         ...                         13.0     Newcastle United
# 65         ...                         13.0     Newcastle United
# 72         ...                         13.0     Newcastle United
# 77         ...                         13.0     Newcastle United
# 84         ...                         13.0     Newcastle United
# 92         ...                         13.0     Newcastle United
# 102        ...                         13.0     Newcastle United
# 109        ...                         13.0     Newcastle United
# 112        ...                         13.0     Newcastle United
# 116        ...                         13.0     Newcastle United
# 120        ...                         13.0     Newcastle United
# 121        ...                         13.0     Newcastle United
# 136        ...                         19.0      West Ham United
# 143        ...                         19.0      West Ham United
# 150        ...                         19.0      West Ham United
# 157        ...                         19.0      West Ham United
# 164        ...                         19.0      West Ham United
# 179        ...                         19.0      West Ham United
# 186        ...                         19.0      West Ham United
# 193        ...                         19.0      West Ham United
# 199        ...                         19.0      West Ham United
# 206        ...                         19.0      West Ham United
# 211        ...                         19.0      West Ham United
# ...        ...                          ...                  ...
# 2725       ...                       1793.0              Reading
# 2726       ...                       1793.0              Reading
# 2727       ...                       1793.0              Reading
# 2728       ...                       1793.0              Reading
# 2729       ...                       1793.0              Reading
# 2730       ...                       1793.0              Reading
# 2731       ...                       1793.0              Reading
# 2732       ...                       1793.0              Reading
# 2733       ...                       1793.0              Reading
# 2734       ...                       1793.0              Reading
# 2735       ...                       1793.0              Reading
# 2892       ...                         11.0    Manchester United
# 2900       ...                         11.0    Manchester United
# 2907       ...                         11.0    Manchester United
# 2915       ...                         11.0    Manchester United
# 2923       ...                         11.0    Manchester United
# 2940       ...                         11.0    Manchester United
# 2948       ...                         11.0    Manchester United
# 2956       ...                         11.0    Manchester United
# 2963       ...                         11.0    Manchester United
# 2971       ...                         11.0    Manchester United
# 2977       ...                         11.0    Manchester United
# 2984       ...                         11.0    Manchester United
# 2994       ...                         11.0    Manchester United
# 3006       ...                         11.0    Manchester United
# 3016       ...                         11.0    Manchester United
# 3019       ...                         11.0    Manchester United
# 3023       ...                         11.0    Manchester United
# 3027       ...                         11.0    Manchester United
# 3028       ...                         11.0    Manchester United
#
#       team_short_name_away  home_possession  total_prob  pct_win_prob  \
# 3                      NEW               50    1.050441      0.780312
# 10                     NEW               50    1.059524      0.655431
# 17                     NEW               50    1.050253      0.380861
# 23                     NEW               50    1.021978      0.411132
# 30                     NEW               50    1.023561      0.336890
# 37                     NEW               50    1.055812      0.547479
# 51                     NEW               50    1.051460      0.634039
# 58                     NEW               50    1.055773      0.495902
# 65                     NEW               50    1.053609      0.604534
# 72                     NEW               50    1.051338      0.497994
# 77                     NEW               50    1.022715      0.585502
# 84                     NEW               50    1.024276      0.433911
# 92                     NEW               50    1.024607      0.733823
# 102                    NEW               50    1.023018      0.425000
# 109                    NEW               50    1.023018      0.287500
# 112                    NEW               50    1.026441      0.442836
# 116                    NEW               50    1.020635      0.466563
# 120                    NEW               50    1.050253      0.330608
# 121                    NEW               50    1.053830      0.412574
# 136                    WHU               50    1.056852      0.775579
# 143                    WHU               50    1.029971      0.674237
# 150                    WHU               50    1.026229      0.409429
# 157                    WHU               50    1.021568      0.372201
# 164                    WHU               50    1.022222      0.652174
# 179                    WHU               50    1.025397      0.696594
# 186                    WHU               50    1.022809      0.454744
# 193                    WHU               50    1.028223      0.715111
# 199                    WHU               50    1.053756      0.486660
# 206                    WHU               50    1.025974      0.443038
# 211                    WHU               50    1.047287      0.571765
# ...                    ...              ...         ...           ...
# 2725                   REA               50    1.051880      0.714796
# 2726                   REA               50    1.021429      0.559441
# 2727                   REA               50    1.024921      0.563980
# 2728                   REA               50    1.051880      0.714796
# 2729                   REA               50    1.055228      0.547782
# 2730                   REA               50    1.054825      0.831601
# 2731                   REA               50    1.055173      0.517875
# 2732                   REA               50    1.055556      0.526316
# 2733                   REA               50    1.025063      0.557457
# 2734                   REA               50    1.051338      0.497994
# 2735                   REA               50    1.051338      0.497994
# 2892                   MUN               50    1.025253      0.433498
# 2900                   MUN               50    1.022727      0.162963
# 2907                   MUN               50    1.026464      0.177131
# 2915                   MUN               50    1.059524      0.134831
# 2923                   MUN               50    1.055173      0.218871
# 2940                   MUN               50    1.055612      0.394716
# 2948                   MUN               50    1.024267      0.139473
# 2956                   MUN               50    1.053629      0.351519
# 2963                   MUN               50    1.051210      0.226496
# 2971                   MUN               50    1.025974      0.177215
# 2977                   MUN               50    1.022605      0.337205
# 2984                   MUN               50    1.025081      0.216785
# 2994                   MUN               50    1.052760      0.431766
# 3006                   MUN               50    1.058357      0.157477
# 3016                   MUN               50    1.027399      0.139047
# 3019                   MUN               50    1.059524      0.134831
# 3023                   MUN               50    1.048802      0.190694
# 3027                   MUN               50    1.058145      0.126007
# 3028                   MUN               50    1.058357      0.157477
#
#       expected  resulty  other_expected  final_expected
# 3     0.779633      1.0        0.904709        0.668747
# 10    0.654674      1.0        0.785690        0.586200
# 17    0.431984      0.5        0.493696        0.456731
# 23    0.543230      0.5        0.752104        0.487306
# 30    0.485101      0.0        0.583613        0.471259
# 37    0.534850      0.5        0.634882        0.515422
# 51    0.520867      1.0        0.536452        0.543280
# 58    0.510324      1.0        0.751507        0.478501
# 65    0.421464      0.5        0.438400        0.477118
# 72    0.496220      1.0        0.478215        0.488579
# 77    0.681468      1.0        0.763701        0.596617
# 84    0.524227      0.5        0.469893        0.502832
# 92    0.748321      1.0        0.729094        0.661246
# 102   0.419105      1.0        0.363567        0.439088
# 109   0.413204      0.0        0.357365        0.429512
# 112   0.545876      0.5        0.570987        0.502392
# 116   0.540713      1.0        0.410047        0.509866
# 120   0.361312      0.5        0.199085        0.447394
# 121   0.397753      1.0        0.467447        0.448280
# 136   0.746429      1.0        0.825214        0.675408
# 143   0.653630      1.0        0.678073        0.612685
# 150   0.488509      1.0        0.535512        0.497690
# 157   0.458305      1.0        0.405144        0.487255
# 164   0.667166      1.0        0.624927        0.613756
# 179   0.706863      1.0        0.753432        0.643021
# 186   0.590362      0.0        0.651589        0.541350
# 193   0.661020      0.5        0.767486        0.588229
# 199   0.595229      0.0        0.609270        0.557966
# 206   0.533509      1.0        0.575130        0.528576
# 211   0.553134      1.0        0.397012        0.570521
# ...        ...      ...             ...             ...
# 2725  0.524440      1.0        0.621005        0.521337
# 2726  0.542465      0.0        0.391478        0.534395
# 2727  0.624687      0.0        0.680273        0.561650
# 2728  0.743395      1.0        0.891852        0.631025
# 2729  0.561307      1.0        0.692324        0.505975
# 2730  0.838090      1.0        0.942526        0.695422
# 2731  0.496981      1.0        0.431551        0.476096
# 2732  0.438645      0.5        0.437933        0.458289
# 2733  0.592065      1.0        0.603379        0.544886
# 2734  0.512024      0.5        0.484812        0.503482
# 2735  0.522121      1.0        0.614501        0.503224
# 2892  0.355056      0.5        0.409393        0.398837
# 2900  0.135423      0.0        0.043338        0.256622
# 2907  0.158772      0.5        0.144539        0.258993
# 2915  0.198347      0.0        0.095957        0.313777
# 2923  0.379273      1.0        0.485090        0.403293
# 2940  0.463542      0.0        0.620987        0.459408
# 2948  0.138971      0.0        0.042789        0.262998
# 2956  0.258913      0.0        0.136247        0.364318
# 2963  0.374462      0.0        0.357479        0.396820
# 2971  0.190866      0.0        0.086132        0.302906
# 2977  0.316030      0.5        0.256932        0.390688
# 2984  0.169934      0.5        0.084269        0.275077
# 2994  0.497193      0.0        0.466755        0.483164
# 3006  0.170395      0.0        0.077035        0.275141
# 3016  0.126918      0.0        0.056431        0.239655
# 3019  0.220124      1.0        0.101159        0.325137
# 3023  0.235743      0.5        0.143545        0.325463
# 3027  0.197275      0.0        0.087651        0.313251
# 3028  0.284732      0.0        0.206823        0.360976
#
# [380 rows x 132 columns]

# %%
with_team_names.loc[:, 'resulty'] = with_team_names.apply(lambda x: calculate_result(x), axis=1)
with_team_names.head()
# Out:
#      id  country_id  league_id     season  stage                 date  \
# 0  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1  2494        1729       1729  2010/2011      1  2010-08-16 00:00:00
# 2  2913        1729       1729  2011/2012     13  2011-11-26 00:00:00
# 3  3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 4  3693        1729       1729  2013/2014     15  2013-12-07 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal   ...     \
# 0        489042             10260             10261               1   ...
# 1        839802             10260             10261               3   ...
# 2       1024845             10260             10261               1   ...
# 3       1229300             10260             10261               4   ...
# 4       1474518             10260             10261               0   ...
#
#    id_away  team_api_id_away  team_fifa_api_id_away  team_long_name_away  \
# 0     3458             10261                   13.0     Newcastle United
# 1     3458             10261                   13.0     Newcastle United
# 2     3458             10261                   13.0     Newcastle United
# 3     3458             10261                   13.0     Newcastle United
# 4     3458             10261                   13.0     Newcastle United
#
#    team_short_name_away  home_possession  total_prob  pct_win_prob  expected  \
# 0                   NEW               50    1.047921      0.739744  0.500000
# 1                   NEW               50    1.048485      0.763006  0.744386
# 2                   NEW               50    1.054155      0.677591  0.648628
# 3                   NEW               50    1.050441      0.780312  0.779633
# 4                   NEW               50    1.027399      0.636165  0.629053
#
#    resulty
# 0      0.5
# 1      1.0
# 2      0.5
# 3      1.0
# 4      0.0
#
# [5 rows x 130 columns]

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(with_team_names.resulty, with_team_names.pct_win_prob)
# Out:
# 0.16656785679413874

# %%
mean_squared_error(with_team_names.resulty, with_team_names.expected)
# Out:
# 0.16245081868874653

# %%
mean_squared_error(with_team_names.resulty, with_team_names.final_expected)
# Out:
# 0.16546206236139085

# %%
mean_squared_error(with_team_names.resulty, with_team_names.other_expected)
# Out:
# 0.18089134019391082

# %%
with_team_names.loc[:, 'label'] = with_team_names.apply(lambda x: get_match_label(x), axis=1)
with_team_names.head()
# Out:
#      id  country_id  league_id     season  stage                 date  \
# 0  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1  2494        1729       1729  2010/2011      1  2010-08-16 00:00:00
# 2  2913        1729       1729  2011/2012     13  2011-11-26 00:00:00
# 3  3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 4  3693        1729       1729  2013/2014     15  2013-12-07 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal   ...    \
# 0        489042             10260             10261               1   ...
# 1        839802             10260             10261               3   ...
# 2       1024845             10260             10261               1   ...
# 3       1229300             10260             10261               4   ...
# 4       1474518             10260             10261               0   ...
#
#    team_long_name_away  team_short_name_away  home_possession  total_prob  \
# 0     Newcastle United                   NEW               50    1.047921
# 1     Newcastle United                   NEW               50    1.048485
# 2     Newcastle United                   NEW               50    1.054155
# 3     Newcastle United                   NEW               50    1.050441
# 4     Newcastle United                   NEW               50    1.027399
#
#    pct_win_prob  expected  resulty  other_expected  final_expected   label
# 0      0.739744  0.500000      0.5        0.500000        0.500000    Draw
# 1      0.763006  0.744386      1.0        0.863552        0.638373     Win
# 2      0.677591  0.648628      0.5        0.616338        0.625910    Draw
# 3      0.780312  0.779633      1.0        0.904709        0.668747     Win
# 4      0.636165  0.629053      0.0        0.466635        0.626356  Defeat
#
# [5 rows x 133 columns]

# %%
import datetime
get_last_matches_against_eachother(with_team_names, '2013-07-01', 10260, 10261, x = 25)
# Out:
#         id  country_id  league_id     season  stage                 date  \
# 3     3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 2963  3602        1729       1729  2012/2013      7  2012-10-07 00:00:00
# 2962  2994        1729       1729  2011/2012     20  2012-01-04 00:00:00
# 2     2913        1729       1729  2011/2012     13  2011-11-26 00:00:00
# 2961  2753        1729       1729  2010/2011     33  2011-04-19 00:00:00
# 1     2494        1729       1729  2010/2011      1  2010-08-16 00:00:00
# 2960  1935        1729       1729  2008/2009     28  2009-03-04 00:00:00
# 0     1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
#
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 3          1229300             10260             10261               4
# 2963       1229165             10261             10260               0
# 2962       1025212             10261             10260               3
# 2          1024845             10260             10261               1
# 2961        840178             10261             10260               0
# 1           839802             10260             10261               3
# 2960        489319             10261             10260               1
# 0           489042             10260             10261               1
#
#        ...    team_long_name_away  team_short_name_away  home_possession  \
# 3      ...       Newcastle United                   NEW               50
# 2963   ...      Manchester United                   MUN               50
# 2962   ...      Manchester United                   MUN               50
# 2      ...       Newcastle United                   NEW               50
# 2961   ...      Manchester United                   MUN               50
# 1      ...       Newcastle United                   NEW               50
# 2960   ...      Manchester United                   MUN               50
# 0      ...       Newcastle United                   NEW               50
#
#       total_prob  pct_win_prob  expected  resulty  other_expected  \
# 3       1.050441      0.780312  0.779633      1.0        0.904709
# 2963    1.051210      0.226496  0.374462      0.0        0.357479
# 2962    1.055812      0.189428  0.278150      1.0        0.162293
# 2       1.054155      0.677591  0.648628      0.5        0.616338
# 2961    1.058398      0.171786  0.220524      0.5        0.142241
# 1       1.048485      0.763006  0.744386      1.0        0.863552
# 2960    1.050000      0.126984  0.205180      0.0        0.059601
# 0       1.047921      0.739744  0.500000      0.5        0.500000
#
#       final_expected   label
# 3           0.668747     Win
# 2963        0.396820  Defeat
# 2962        0.345183     Win
# 2           0.625910    Draw
# 2961        0.305839    Draw
# 1           0.638373     Win
# 2960        0.365876  Defeat
# 0           0.500000    Draw
#
# [8 rows x 133 columns]

# %%
def get_home_recent_score(match, all_matches):
    last_matches = get_last_matches(
        all_matches,
        match.date,
        match.home_team_api_id,
        x = 10
    )
    score = calculate_team_score(last_matches, match)
    return score

def get_away_recent_score(match, all_matches):
    last_matches = get_last_matches(
        all_matches,
        match.date,
        match.away_team_api_id,
        x = 10
    )
    score = calculate_away_team_score(last_matches, match)
    return score

def get_team_score(match, all_matches):
    last_matches = get_last_matches_against_eachother(
        all_matches,
        match.date,
        match.home_team_api_id,
        match.away_team_api_id,
        x = 25
    )
    score = calculate_team_score(last_matches, match)
    return score

def calculate_team_score(matches, this_match):
    home_matches = matches[matches.home_team_api_id == this_match.home_team_api_id]
    away_matches = matches[matches.away_team_api_id == this_match.home_team_api_id]
    home_offensive_score, home_defensive_score = get_home_score(home_matches)
    away_offensive_score, away_defensive_score = get_away_score(away_matches)
    return (home_offensive_score, home_defensive_score, away_offensive_score, away_defensive_score)

def calculate_away_team_score(matches, this_match):
    home_matches = matches[matches.home_team_api_id == this_match.away_team_api_id]
    away_matches = matches[matches.away_team_api_id == this_match.away_team_api_id]
    home_offensive_score, home_defensive_score = get_home_score(home_matches)
    away_offensive_score, away_defensive_score = get_away_score(away_matches)
    return (home_offensive_score, home_defensive_score, away_offensive_score, away_defensive_score)

def get_home_score(matches):
    total_offensive_score = 0
    total_defensive_score = 0
    for index, match in enumerate(matches.itertuples(index=False, name='Pandas')):
        offensive_score = match.home_team_goal / (index + 1)
        defensive_score = match.away_team_goal / (index + 1)
        total_offensive_score += offensive_score
        total_defensive_score -= defensive_score
    return (total_offensive_score, total_defensive_score)

def get_away_score(matches):
    total_offensive_score = 0
    total_defensive_score = 0
    for index, match in enumerate(matches.itertuples(index=False, name='Pandas')):
        offensive_score = match.away_team_goal / (index + 1)
        defensive_score = match.home_team_goal / (index + 1)
        total_offensive_score += offensive_score
        total_defensive_score -= defensive_score
    return (total_offensive_score, total_defensive_score)

# %%
good = with_team_names.apply(lambda x: list(get_team_score(x, with_team_names)), axis=1)

# %%
match_stats = pd.DataFrame(good.tolist(), columns = ['home_offensive', 'home_defensive', 'away_offensive', 'away_defensive'])
match_stats.head()
# Out:
#    home_offensive  home_defensive  away_offensive  away_defensive
# 0        0.000000        0.000000             0.0            0.00
# 1        1.000000       -1.000000             2.0           -1.00
# 2        3.500000       -0.500000             1.0           -0.50
# 3        2.833333       -1.333333             3.5           -1.75
# 4        5.750000       -3.750000             3.5           -1.75

# %%
new_frame = pd.concat([with_team_names, match_stats], axis=1)
new_frame.head()
# Out:
#      id  country_id  league_id     season  stage                 date  \
# 0  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1  2494        1729       1729  2010/2011      1  2010-08-16 00:00:00
# 2  2913        1729       1729  2011/2012     13  2011-11-26 00:00:00
# 3  3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 4  3693        1729       1729  2013/2014     15  2013-12-07 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0        489042             10260             10261               1
# 1        839802             10260             10261               3
# 2       1024845             10260             10261               1
# 3       1229300             10260             10261               4
# 4       1474518             10260             10261               0
#
#         ...        pct_win_prob  expected  resulty  other_expected  \
# 0       ...            0.739744  0.500000      0.5        0.500000
# 1       ...            0.763006  0.744386      1.0        0.863552
# 2       ...            0.677591  0.648628      0.5        0.616338
# 3       ...            0.780312  0.779633      1.0        0.904709
# 4       ...            0.636165  0.629053      0.0        0.466635
#
#    final_expected   label  home_offensive  home_defensive  away_offensive  \
# 0        0.500000    Draw        0.000000        0.000000             0.0
# 1        0.638373     Win        1.000000       -1.000000             2.0
# 2        0.625910    Draw        3.500000       -0.500000             1.0
# 3        0.668747     Win        2.833333       -1.333333             3.5
# 4        0.626356  Defeat        5.750000       -3.750000             3.5
#
#    away_defensive
# 0            0.00
# 1           -1.00
# 2           -0.50
# 3           -1.75
# 4           -1.75
#
# [5 rows x 137 columns]

# %%
home_mebs = with_team_names.apply(lambda x: list(get_home_recent_score(x, with_team_names)), axis=1)

# %%
home_match_stats = pd.DataFrame(home_mebs.tolist(), columns = ['home_recent_offensive', 'home_recent_defensive', 'away_recent_offensive', 'away_recent_defensive'])
home_match_stats.head()
# Out:
#    home_recent_offensive  home_recent_defensive  away_recent_offensive  \
# 0               0.000000               0.000000               0.000000
# 1               6.933333              -1.416667               2.700000
# 2               4.516667              -3.650000               3.083333
# 3               5.000000              -1.583333               4.933333
# 4               1.950000              -2.316667               4.700000
#
#    away_recent_defensive
# 0               0.000000
# 1               0.000000
# 2              -0.583333
# 3              -3.983333
# 4              -4.383333

# %%
away_mebs = with_team_names.apply(lambda x: list(get_away_recent_score(x, with_team_names)), axis=1)
away_match_stats = pd.DataFrame(away_mebs.tolist(), columns = ['home_recent_offensive_away', 'home_recent_defensive_away', 'away_recent_offensive_away', 'away_recent_defensive_away'])
away_match_stats.head()
# Out:
#    home_recent_offensive_away  home_recent_defensive_away  \
# 0                    0.000000                    0.000000
# 1                    1.700000                   -2.600000
# 2                    4.316667                   -2.116667
# 3                    3.083333                   -2.366667
# 4                    4.566667                   -2.600000
#
#    away_recent_offensive_away  away_recent_defensive_away
# 0                    0.000000                    0.000000
# 1                    0.450000                   -3.283333
# 2                    3.416667                   -4.083333
# 3                    1.750000                   -3.916667
# 4                    1.733333                   -4.516667

# %%
final_frame = pd.concat([new_frame, home_match_stats, away_match_stats], axis=1)
final_frame.head()
# Out:
#      id  country_id  league_id     season  stage                 date  \
# 0  1729        1729       1729  2008/2009      1  2008-08-17 00:00:00
# 1  2494        1729       1729  2010/2011      1  2010-08-16 00:00:00
# 2  2913        1729       1729  2011/2012     13  2011-11-26 00:00:00
# 3  3353        1729       1729  2012/2013     19  2012-12-26 00:00:00
# 4  3693        1729       1729  2013/2014     15  2013-12-07 00:00:00
#
#    match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 0        489042             10260             10261               1
# 1        839802             10260             10261               3
# 2       1024845             10260             10261               1
# 3       1229300             10260             10261               4
# 4       1474518             10260             10261               0
#
#               ...              away_offensive  away_defensive  \
# 0             ...                         0.0            0.00
# 1             ...                         2.0           -1.00
# 2             ...                         1.0           -0.50
# 3             ...                         3.5           -1.75
# 4             ...                         3.5           -1.75
#
#    home_recent_offensive  home_recent_defensive  away_recent_offensive  \
# 0               0.000000               0.000000               0.000000
# 1               6.933333              -1.416667               2.700000
# 2               4.516667              -3.650000               3.083333
# 3               5.000000              -1.583333               4.933333
# 4               1.950000              -2.316667               4.700000
#
#    away_recent_defensive  home_recent_offensive_away  \
# 0               0.000000                    0.000000
# 1               0.000000                    1.700000
# 2              -0.583333                    4.316667
# 3              -3.983333                    3.083333
# 4              -4.383333                    4.566667
#
#    home_recent_defensive_away  away_recent_offensive_away  \
# 0                    0.000000                    0.000000
# 1                   -2.600000                    0.450000
# 2                   -2.116667                    3.416667
# 3                   -2.366667                    1.750000
# 4                   -2.600000                    1.733333
#
#    away_recent_defensive_away
# 0                    0.000000
# 1                   -3.283333
# 2                   -4.083333
# 3                   -3.916667
# 4                   -4.516667
#
# [5 rows x 145 columns]

# %%
final_frame.columns.values
# Out:
# array(['id', 'country_id', 'league_id', 'season', 'stage', 'date',
#        'match_api_id', 'home_team_api_id', 'away_team_api_id',
#        'home_team_goal', 'away_team_goal', 'home_player_X1',
#        'home_player_X2', 'home_player_X3', 'home_player_X4',
#        'home_player_X5', 'home_player_X6', 'home_player_X7',
#        'home_player_X8', 'home_player_X9', 'home_player_X10',
#        'home_player_X11', 'away_player_X1', 'away_player_X2',
#        'away_player_X3', 'away_player_X4', 'away_player_X5',
#        'away_player_X6', 'away_player_X7', 'away_player_X8',
#        'away_player_X9', 'away_player_X10', 'away_player_X11',
#        'home_player_Y1', 'home_player_Y2', 'home_player_Y3',
#        'home_player_Y4', 'home_player_Y5', 'home_player_Y6',
#        'home_player_Y7', 'home_player_Y8', 'home_player_Y9',
#        'home_player_Y10', 'home_player_Y11', 'away_player_Y1',
#        'away_player_Y2', 'away_player_Y3', 'away_player_Y4',
#        'away_player_Y5', 'away_player_Y6', 'away_player_Y7',
#        'away_player_Y8', 'away_player_Y9', 'away_player_Y10',
#        'away_player_Y11', 'home_player_1', 'home_player_2',
#        'home_player_3', 'home_player_4', 'home_player_5', 'home_player_6',
#        'home_player_7', 'home_player_8', 'home_player_9',
#        'home_player_10', 'home_player_11', 'away_player_1',
#        'away_player_2', 'away_player_3', 'away_player_4', 'away_player_5',
#        'away_player_6', 'away_player_7', 'away_player_8', 'away_player_9',
#        'away_player_10', 'away_player_11', 'goal', 'shoton', 'shotoff',
#        'foulcommit', 'card', 'cross', 'corner', 'possession', 'B365H',
#        'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'LBH',
#        'LBD', 'LBA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'SJH',
#        'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'GBH', 'GBD', 'GBA', 'BSH',
#        'BSD', 'BSA', 'id_home', 'team_api_id', 'team_fifa_api_id',
#        'team_long_name', 'team_short_name', 'id_away', 'team_api_id_away',
#        'team_fifa_api_id_away', 'team_long_name_away',
#        'team_short_name_away', 'home_possession', 'total_prob',
#        'pct_win_prob', 'expected', 'resulty', 'other_expected',
#        'final_expected', 'label', 'home_offensive', 'home_defensive',
#        'away_offensive', 'away_defensive', 'home_recent_offensive',
#        'home_recent_defensive', 'away_recent_offensive',
#        'away_recent_defensive', 'home_recent_offensive_away',
#        'home_recent_defensive_away', 'away_recent_offensive_away',
#        'away_recent_defensive_away'], dtype=object)

# %%
X = final_frame[['expected', 'other_expected',
       'final_expected', 'home_offensive', 'home_defensive',
       'away_offensive', 'away_defensive', 'home_recent_offensive',
       'home_recent_defensive', 'away_recent_offensive',
       'away_recent_defensive', 'home_recent_offensive_away',
       'home_recent_defensive_away', 'away_recent_offensive_away',
       'away_recent_defensive_away']].values
y = final_frame.label.values

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X, y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
lr.predict(X)
# Out:
# array(['Win', 'Win', 'Win', ..., 'Win', 'Defeat', 'Defeat'], dtype=object)

# %%
lr.predict_proba(X)
# Out:
# array([[0.22983688, 0.2402297 , 0.52993343],
#        [0.09988525, 0.15518307, 0.74493168],
#        [0.14176646, 0.22395911, 0.63427443],
#        ...,
#        [0.35301965, 0.23931507, 0.40766528],
#        [0.46162257, 0.26087584, 0.27750159],
#        [0.40159702, 0.26411733, 0.33428564]])

# %%
lr.score(X, y)
# Out:
# 0.5190789473684211

# %%
lr.predict_proba(X)[-5:]
# Out:
# array([[0.4529658 , 0.30747051, 0.23956369],
#        [0.38387643, 0.26157754, 0.35454604],
#        [0.35301965, 0.23931507, 0.40766528],
#        [0.46162257, 0.26087584, 0.27750159],
#        [0.40159702, 0.26411733, 0.33428564]])

# %%
y[-5:]
# Out:
# array(['Draw', 'Win', 'Draw', 'Win', 'Defeat'], dtype=object)

# %%
final_frame[['home_team_goal', 'away_team_goal', 'team_long_name', 'team_long_name_away']].tail()
# Out:
#       home_team_goal  away_team_goal  team_long_name team_long_name_away
# 3035               2               2    Cardiff City   Manchester United
# 3036               5               3  Leicester City   Manchester United
# 3037               1               1  Leicester City   Manchester United
# 3038               2               1     Bournemouth   Manchester United
# 3039               1               2         Watford   Manchester United

# %%
final_frame.loc[:, 'pct_draw_prob'] = (1./ final_frame.B365D) / final_frame.total_prob
final_frame.loc[:, 'pct_lose_prob'] = (1./ final_frame.B365A) / final_frame.total_prob
final_frame[['pct_win_prob','pct_draw_prob', 'pct_lose_prob']].head()
# Out:
#    pct_win_prob  pct_draw_prob  pct_lose_prob
# 0      0.739744       0.173504       0.086752
# 1      0.763006       0.173410       0.063584
# 2      0.677591       0.210806       0.111603
# 3      0.780312       0.146459       0.073229
# 4      0.636165       0.224788       0.139047

# %%
lr.predict_proba(X)[-5:]
# Out:
# array([[0.4529658 , 0.30747051, 0.23956369],
#        [0.38387643, 0.26157754, 0.35454604],
#        [0.35301965, 0.23931507, 0.40766528],
#        [0.46162257, 0.26087584, 0.27750159],
#        [0.40159702, 0.26411733, 0.33428564]])

# %%
final_frame[['pct_win_prob', 'pct_draw_prob', 'pct_lose_prob']].tail()
# Out:
#       pct_win_prob  pct_draw_prob  pct_lose_prob
# 3035      0.162963       0.244444       0.592593
# 3036      0.178478       0.233721       0.587801
# 3037      0.314725       0.278756       0.406519
# 3038      0.287500       0.287500       0.425000
# 3039      0.225300       0.286926       0.487774

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

ohe = OneHotEncoder()
le = LabelEncoder()
better = ohe.fit_transform(le.fit_transform(y).reshape(-1, 1))

# %%
from sklearn.metrics import log_loss

log_loss(better.toarray(), lr.predict_proba(X))
# Out:
# 0.9905079832393577

# %%
log_loss(better.toarray(), final_frame[['pct_win_prob', 'pct_draw_prob', 'pct_lose_prob']].values)
# Out:
# 1.4436242890429998

# %%
from sklearn.model_selection import ShuffleSplit

rs = ShuffleSplit(n_splits=3, test_size=.2, random_state=0)
for train_index, test_index in rs.split(X):
    train_x = X[train_index]
    train_y = y[train_index]
    test_x = X[test_index]
    test_y = y[test_index]
    lr = LogisticRegression()
    lr.fit(train_x, train_y)
    
    ohe = OneHotEncoder()
    le = LabelEncoder()
    better = ohe.fit_transform(le.fit_transform(train_y).reshape(-1, 1))
    
    print("Train loss: {0:.3f}".format(log_loss(better.toarray(), lr.predict_proba(train_x))))
    
    test_better = ohe.transform(le.transform(test_y).reshape(-1, 1))
    
    print("Test loss: {0:.3f}".format(log_loss(test_better.toarray(), lr.predict_proba(test_x))))
# Out:
# Train loss: 0.992
# Test loss: 0.992
# Train loss: 0.997
# Test loss: 0.970
# Train loss: 0.984
# Test loss: 1.021

# %%
from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import ShuffleSplit

rs = ShuffleSplit(n_splits=3, test_size=.2, random_state=0)
for train_index, test_index in rs.split(X):
    train_x = X[train_index]
    train_y = y[train_index]
    test_x = X[test_index]
    test_y = y[test_index]
    lr = LogisticRegression()
    #pf = PolynomialFeatures()
    #new_train_x = pf.fit_transform(train_x)
    #new_test_x = pf.transform(test_x)
    lr.fit(train_x, train_y)
    
    ohe = OneHotEncoder()
    le = LabelEncoder()
    better = ohe.fit_transform(le.fit_transform(train_y).reshape(-1, 1))
    
    print("Train loss: {0:.3f}".format(log_loss(better.toarray(), lr.predict_proba(train_x))))
    
    test_better = ohe.transform(le.transform(test_y).reshape(-1, 1))
    
    print("Test loss: {0:.3f}".format(log_loss(test_better.toarray(), lr.predict_proba(test_x))))
# Out:
# Train loss: 0.992
# Test loss: 0.992
# Train loss: 0.997
# Test loss: 0.970
# Train loss: 0.984
# Test loss: 1.021

# %%
from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import ShuffleSplit

from sklearn.ensemble import RandomForestClassifier

rs = ShuffleSplit(n_splits=3, test_size=.1, random_state=382)
for train_index, test_index in rs.split(X):
    train_x = X[train_index]
    train_y = y[train_index]
    test_x = X[test_index]
    test_y = y[test_index]
    rf = RandomForestClassifier(max_depth=3, min_samples_split=3, min_samples_leaf=2)
    pf = PolynomialFeatures()
    new_train_x = pf.fit_transform(train_x)
    new_test_x = pf.transform(test_x)
    rf.fit(new_train_x, train_y)
    
    ohe = OneHotEncoder()
    le = LabelEncoder()
    better = ohe.fit_transform(le.fit_transform(train_y).reshape(-1, 1))
    
    print("Train loss: {0:.3f}".format(log_loss(better.toarray(), rf.predict_proba(new_train_x))))
    
    test_better = ohe.transform(le.transform(test_y).reshape(-1, 1))
    
    print("Test loss: {0:.3f}".format(log_loss(test_better.toarray(), rf.predict_proba(new_test_x))))
# Out:
# Train loss: 0.975
# Test loss: 1.021
# Train loss: 0.971
# Test loss: 1.027
# Train loss: 0.976
# Test loss: 0.998

# %%
from sklearn.preprocessing import PolynomialFeatures

from sklearn.model_selection import ShuffleSplit

from sklearn.ensemble import RandomForestClassifier

from sklearn.ensemble import GradientBoostingClassifier

rs = ShuffleSplit(n_splits=3, test_size=.1, random_state=18)
for train_index, test_index in rs.split(X):
    train_x = X[train_index]
    train_y = y[train_index]
    test_x = X[test_index]
    test_y = y[test_index]
    gb = GradientBoostingClassifier(subsample=0.65, min_samples_leaf=3, min_samples_split=4)
    #pf = PolynomialFeatures(interaction_only=True, include_bias=False)
    #new_train_x = pf.fit_transform(train_x)
    #new_test_x = pf.transform(test_x)
    gb.fit(train_x, train_y)
    
    ohe = OneHotEncoder()
    le = LabelEncoder()
    better = ohe.fit_transform(le.fit_transform(train_y).reshape(-1, 1))
    
    print("Train loss: {0:.3f}".format(log_loss(better.toarray(), gb.predict_proba(train_x))))
    
    test_better = ohe.transform(le.transform(test_y).reshape(-1, 1))
    
    print("Test loss: {0:.3f}".format(log_loss(test_better.toarray(), gb.predict_proba(test_x))))
# Out:
# Train loss: 0.780
# Test loss: 0.964
# Train loss: 0.778
# Test loss: 0.976
# Train loss: 0.773
# Test loss: 1.010

# %%
for label, coef in zip(['bias', 'expected', 'other_expected',
       'final_expected', 'home_offensive', 'home_defensive',
       'away_offensive', 'away_defensive', 'home_recent_offensive',
       'home_recent_defensive', 'away_recent_offensive',
       'away_recent_defensive', 'home_recent_offensive_away',
       'home_recent_defensive_away', 'away_recent_offensive_away',
       'away_recent_defensive_away'], lr.coef_[0]):
    print("{0} : {1:.2f}".format(label, coef))
# Out:
# bias : -3.26
# expected : 0.75
# other_expected : -2.58
# final_expected : 0.01
# home_offensive : -0.06
# home_defensive : -0.07
# away_offensive : -0.01
# away_defensive : -0.01
# home_recent_offensive : -0.02
# home_recent_defensive : -0.05
# away_recent_offensive : -0.00
# away_recent_defensive : 0.05
# home_recent_offensive_away : 0.01
# home_recent_defensive_away : -0.00
# away_recent_offensive_away : 0.01

# %%
lr.predict_proba(X)[:5]
# Out:
# array([[0.25491503, 0.22298487, 0.5221001 ],
#        [0.10223591, 0.15280609, 0.744958  ],
#        [0.14887169, 0.21451982, 0.63660849],
#        [0.0836525 , 0.19070104, 0.72564646],
#        [0.14334423, 0.25103377, 0.605622  ]])

# %%
final_frame[['pct_win_prob', 'pct_draw_prob', 'pct_lose_prob']].values[:5]
# Out:
# array([[0.73974445, 0.1735037 , 0.08675185],
#        [0.76300578, 0.1734104 , 0.06358382],
#        [0.67759079, 0.21080602, 0.11160319],
#        [0.78031212, 0.14645858, 0.07322929],
#        [0.63616463, 0.22478796, 0.13904741]])

# %%
draw_predictions = final_frame[(lr.predict_proba(X)[:, 1] - final_frame.pct_draw_prob ) <= 0.]

# %%
BET = 1
RUNNING_TOTAL = 0
CORRECT_COUNT = 0

for index, row in draw_predictions.sort_values(by='date').iterrows():
    odds = row.B365D
    result = row.label
    if result == 'Draw':
        CORRECT_COUNT += 1
        RUNNING_TOTAL += odds*BET
    else:
        RUNNING_TOTAL -= BET

# %%
print("Money made: {0:.2f}".format(RUNNING_TOTAL))
print("Correct count: {0}".format(CORRECT_COUNT))
# Out:
# Money made: 328.65
# Correct count: 442

# %%
final_frame.sort_values(by='B365D').head()
# Out:
#         id  country_id  league_id     season  stage                 date  \
# 1131  2805        1729       1729  2010/2011     38  2011-05-22 00:00:00
# 2952  2049        1729       1729  2008/2009      4  2008-09-13 00:00:00
# 19    4256        1729       1729  2014/2015     31  2015-04-05 00:00:00
# 1491  4180        1729       1729  2014/2015     25  2015-02-10 00:00:00
# 1037  2844        1729       1729  2010/2011      7  2010-10-02 00:00:00
#
#       match_api_id  home_team_api_id  away_team_api_id  home_team_goal  \
# 1131        840231              8602              8655               2
# 2952        489072              8650             10260               2
# 19         1724289              8472             10261               1
# 1491       1724223              8667             10252               2
# 1037        839879              8658              8668               0
#
#           ...        home_recent_offensive  home_recent_defensive  \
# 1131      ...                     5.050000              -3.250000
# 2952      ...                     2.000000              -1.000000
# 19        ...                     0.500000              -4.866667
# 1491      ...                     1.000000              -3.583333
# 1037      ...                     1.166667              -0.583333
#
#       away_recent_offensive  away_recent_defensive  \
# 1131               3.950000              -3.500000
# 2952               0.500000               0.000000
# 19                 0.950000              -2.816667
# 1491               1.750000              -3.483333
# 1037               2.916667              -5.366667
#
#       home_recent_offensive_away  home_recent_defensive_away  \
# 1131                    2.150000                   -1.983333
# 2952                    1.000000                   -1.000000
# 19                      1.783333                   -3.150000
# 1491                    1.533333                   -3.366667
# 1037                    2.483333                   -3.033333
#
#       away_recent_offensive_away  away_recent_defensive_away  pct_draw_prob  \
# 1131                    1.700000                   -3.550000       0.316092
# 2952                    1.000000                    0.000000       0.317073
# 19                      1.083333                   -6.233333       0.308642
# 1491                    0.000000                   -6.083333       0.313653
# 1037                    0.600000                   -1.233333       0.307211
#
#       pct_lose_prob
# 1131       0.252874
# 2952       0.365854
# 19         0.308642
# 1491       0.277807
# 1037       0.362111
#
# [5 rows x 147 columns]

# %%
with_team_names[['team_long_name', 'team_long_name_away', 'season', 'home_team_goal', 'away_team_goal', 'B365H', 'B365D', 'B365A']].sort_values(by='B365D').head()
# Out:
#                team_long_name team_long_name_away     season  home_team_goal  \
# 1131  Wolverhampton Wanderers    Blackburn Rovers  2010/2011               2
# 2952                Liverpool   Manchester United  2008/2009               2
# 19                 Sunderland    Newcastle United  2014/2015               1
# 1491                Hull City         Aston Villa  2014/2015               2
# 1037          Birmingham City             Everton  2010/2011               0
#
#       away_team_goal  B365H  B365D  B365A
# 1131               3   2.20    3.0   3.75
# 2952               1   3.00    3.0   2.60
# 19                 0   2.50    3.1   3.10
# 1491               0   2.38    3.1   3.50
# 1037               2   2.88    3.1   2.63

# %%
with_team_names[['team_long_name', 'team_long_name_away', 'season', 'home_team_goal', 'away_team_goal', 'B365H', 'B365D', 'B365A']].sort_values(by='B365D', ascending=False).head()
# Out:
#        team_long_name team_long_name_away     season  home_team_goal  \
# 2750  Manchester City        Cardiff City  2013/2014               4
# 683           Chelsea      Wigan Athletic  2009/2010               8
# 2794  Manchester City      Crystal Palace  2013/2014               1
# 1551  Manchester City         Aston Villa  2013/2014               4
# 601   Manchester City          Sunderland  2013/2014               2
#
#       away_team_goal  B365H  B365D  B365A
# 2750               2   1.13   11.0   23.0
# 683                0   1.10   10.0   23.0
# 2794               0   1.13    9.5   29.0
# 1551               0   1.14    9.5   21.0
# 601                2   1.17    9.0   17.0

# %%
final_frame.groupby('label').size() / final_frame.shape[0]
# Out:
# label
# Defeat    0.285197
# Draw      0.257566
# Win       0.457237
# dtype: float64

# %%
final_frame.pct_draw_prob.describe()
# Out:
# count    3040.000000
# mean        0.253598
# std         0.044537
# min         0.089184
# 25%         0.233301
# 50%         0.270977
# 75%         0.287367
# max         0.317181
# Name: pct_draw_prob, dtype: float64

# %%
final_frame.loc[:, 'total_odds'] = final_frame[['B365H', 'B365D', 'B365A']].sum(axis=1)
final_frame.sort_values(by='total_odds', ascending=True).head()[['team_long_name', 'team_long_name_away', 'season', 'home_team_goal', 'away_team_goal', 'B365H', 'B365D', 'B365A']]
# Out:
#             team_long_name team_long_name_away     season  home_team_goal  \
# 2793  West Bromwich Albion      Crystal Palace  2015/2016               3
# 2519      Newcastle United        Swansea City  2013/2014               1
# 903            Southampton             Chelsea  2015/2016               1
# 2492           Aston Villa        Swansea City  2014/2015               0
# 1012            Portsmouth             Everton  2008/2009               2
#
#       away_team_goal  B365H  B365D  B365A
# 2793               2   2.60   3.10   2.80
# 2519               2   2.63   3.30   2.60
# 903                2   2.80   3.25   2.50
# 2492               1   2.50   3.25   2.80
# 1012               1   2.75   3.20   2.62

# %%
final_frame.groupby('season').size()
# Out:
# season
# 2008/2009    380
# 2009/2010    380
# 2010/2011    380
# 2011/2012    380
# 2012/2013    380
# 2013/2014    380
# 2014/2015    380
# 2015/2016    380
# dtype: int64
